# %% [markdown]
# Dallas-Fort Worth has more restaurants per capita than anywhere in the United States. Their cuisine is part of the Texan experience. What comes to mind when someone mentions Texan Cuisine is barbeque.One of the top barbecue restaurants in Dallas is the Pecan Lodge. Despite their success they only have one location on Main Street. As their business continues to grow they may be looking for a second location for their business. To find potental locations we need to find a location that will gather the most attention from tourists, we will also look for any barbeque restaurants in the immediate vicinity. We will analyze data for the most optimal location based on the criteria.The data will show us some locations that hold the most precedence for a second location.

# %% [markdown]
# In this project we will try to find the best potential location to expand their business. We will try to find a location that will gather the most attention from tourists,to give them the opportunity to have a real Texan experience.
# While we look at popular tourist locations, we will also look for any barbeque restaurants in the immediate vicinity.
# We will analyze data for the most optimal location based on the criteria.The data will show us some locations that hold the most precedence for a second location.

# %% [markdown]
# ##### Data

# %% [markdown]
# Things to consider is the number of existing barbecue restaurants in the neighborhood of tourist locations
#
# Generatate information on tourism destinations and the location of number and distance of barbecue restaurants will be obtained using Foursquare API
